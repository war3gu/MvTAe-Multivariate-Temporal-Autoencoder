# %%
# %run stock_reader.py
# Out:
# stockReader
#         ts_code trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ   20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ   20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ   20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ   20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ   20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...        ...      ...      ...      ...      ...        ...
# 1915  000333.SZ   20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ   20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ   20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ   20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ   20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
#       change  pct_chg        vol        amount
# ...

# %%
pip install urllib3
# Out:
# ...
#      |████████████████████████████████| 138 kB 2.8 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.5 MB 2.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 503 kB 93.9 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch
# Out:
# ...
#      |███████████▉                    | 327.2 MB 99.0 MB/s eta 0:00:065             | 231.7 MB 141.9 MB/s eta 0:00:05     |███████████▌                    | 316.9 MB 99.0 MB/s eta 0:00:06
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |███████████████████████▋        | 650.9 MB 123.6 MB/s eta 0:00:02
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ...

# %%
pip install tushare
# Out:
# ...
#      |████████████████████████████████| 130 kB 3.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 53 kB 4.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 62 kB 2.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 136 kB 15.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 6.9 MB 14.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 14.8 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 149 kB 97.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 22.0 MB/s  eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=7960c3c16cd1d77fb97b522bca27d61c3dc50920d7b7249d1ae98d8fbf82c7df
#   Stored in directory: /home/studio-lab-user/.cache/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/sagemaker-studiolab-notebooks/MvTAe-Multivariate-Temporal-Autoencoder/main.py in <module>
#      15
#      16
# ---> 17 from window import window
#      18
#      19 #from defines import *
#
# ~/sagemaker-studiolab-notebooks/MvTAe-Multivariate-Temporal-Autoencoder/window.py in <module>
#      13 from torch.autograd import Variable
#      14 from torch.utils.data import Dataset, TensorDataset, DataLoader
# ---> 15 from torch.utils.tensorboard import SummaryWriter
#      16
#      17 from defines import *
#
# ~/.conda/envs/default/lib/python3.9/site-packages/torch/utils/tensorboard/__init__.py in <module>
# ----> 1 import tensorboard
#       2 from setuptools import distutils
#       3
#       4 LooseVersion = distutils.version.LooseVersion
#       5
#
# ModuleNotFoundError: No module named 'tensorboard'

# %%
pip install tqdm
# Out:
# ...
#      |████████████████████████████████| 76 kB 2.5 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
#      |████████████████████████████████| 26.4 MB 2.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 306 kB 115.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 39.8 MB 77.9 MB/s eta 0:00:01
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=b0abda87349c840576a713cb5b4f3a002d025e13b69c627713f50bd00ab02008
#   Stored in directory: /home/studio-lab-user/.cache/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorboard
# Out:
# ...
#      |████████████████████████████████| 5.8 MB 2.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 781 kB 52.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.9 MB 53.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 93.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.1 MB 98.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 112.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 288 kB 98.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 126 kB 128.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 22.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 94.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 77 kB 18.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 146 kB 111.8 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/sagemaker-studiolab-notebooks/MvTAe-Multivariate-Temporal-Autoencoder/main.py in <module>
#      23 from mvtae_model import MVTAEModel
#      24
# ---> 25 import matplotlib.pyplot as plt
#      26
#      27 import argparse
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 2.6 MB/s eta 0:00:01    |███████████████████████████     | 9.5 MB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.6 MB 80.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 95.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 890 kB 96.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run main.py

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     600196.SH    20211111  50.5000  50.5000  49.5000  49.9400    50.9300
# 1     600196.SH    20211110  48.7900  51.4400  47.6400  50.9300    48.4500
# 2     600196.SH    20211109  47.8100  49.6000  47.7000  48.4500    47.9000
# 3     600196.SH    20211108  48.7600  48.7700  46.6800  47.9000    49.9000
# 4     600196.SH    20211105  49.0000  51.4800  48.7300  49.9000    49.7000
# ...         ...         ...      ...      ...      ...      ...        ...
# 5550  600196.SH    19980813  12.3504  12.8632  12.1955  12.3291    12.3665
# 5551  600196.SH    19980812  11.7521  12.5962  11.5972  12.3665    11.8056
# 5552  600196.SH    19980811  12.9808  13.2318  11.7308  11.8056    13.0342
# 5553  600196.SH    19980810  13.1410  13.7553  12.9701  13.0342    13.1944
# 5554  600196.SH    19980807  13.3547  13.6218  12.6068  13.1944     3.8194
#
# ...

# %%
# %run stock_reader.py
# Out:
#         ts_code  symbol     name  area industry market list_date
# 0     000001.SZ  000001     平安银行    深圳       银行     主板  19910403
# 1     000002.SZ  000002      万科A    深圳     全国地产     主板  19910129
# 2     000004.SZ  000004     国华网安    深圳     软件服务     主板  19910114
# 3     000005.SZ  000005     ST星源    深圳     环境保护     主板  19901210
# 4     000006.SZ  000006     深振业A    深圳     区域地产     主板  19920427
# ...         ...     ...      ...   ...      ...    ...       ...
# 4674  871553.BJ  871553     凯腾精工  None     None    北交所  20210806
# 4675  871642.BJ  871642     通易航天  None     None    北交所  20210816
# 4676  871981.BJ  871981     晶赛科技  None     None    北交所  20211115
# 4677  872925.BJ  872925     锦好医疗  None     None    北交所  20211025
# 4678  689009.SH  689009  九号公司-WD    北京      摩托车    CDR  20201029
#
# [4679 rows x 7 columns]

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 0
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000001.SZ    20211111  17.3500  18.4300  17.3200  18.3500    17.4000
# 1     000001.SZ    20211110  17.4600  17.4700  17.1600  17.4000    17.5300
# 2     000001.SZ    20211109  17.4800  17.6500  17.2600  17.5300    17.4200
# 3     000001.SZ    20211108  17.6200  17.8100  17.3600  17.4200    17.6400
# 4     000001.SZ    20211105  17.8500  18.0000  17.5700  17.6400    17.8700
# ...         ...         ...      ...      ...      ...      ...        ...
# 7255  000001.SZ    19910410   1.9525   1.9525   1.9525   1.9525     1.9623
# 7256  000001.SZ    19910409   1.9623   1.9623   1.9623   1.9623     1.9722
# 7257  000001.SZ    19910408   1.9722   1.9722   1.9722   1.9722     1.9919
# 7258  000001.SZ    19910405   1.9919   1.9919   1.9919   1.9919     2.0017
# 7259  000001.SZ    19910404   2.0017   2.0017   2.0017   2.0017     2.0116
#
# ...

# %%
# %run main.py
# Out:
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/MvTAe-Multivariate-Temporal-Autoencoder/main.py", line 442
#     return
#     ^
# SyntaxError: 'return' outside function

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000333.SZ    20211111  69.1900  72.3600  68.9000  72.0400    69.5800
# 1     000333.SZ    20211110  68.6900  69.8000  68.0200  69.5800    69.0000
# 2     000333.SZ    20211109  70.3500  70.3500  68.3700  69.0000    70.4400
# 3     000333.SZ    20211108  70.6300  70.9600  69.8000  70.4400    70.7500
# 4     000333.SZ    20211105  70.3100  71.8100  69.7900  70.7500    70.7200
# ...         ...         ...      ...      ...      ...      ...        ...
# 1915  000333.SZ    20130926   9.4437   9.5326   8.9784   9.0948     9.5283
# 1916  000333.SZ    20130925   9.3084   9.9704   9.3063   9.5283     9.4353
# 1917  000333.SZ    20130924   9.6214   9.7610   9.3909   9.4353     9.7716
# 1918  000333.SZ    20130923   8.8621   9.8266   8.6019   9.7716     8.9340
# 1919  000333.SZ    20130918   8.5660   9.8139   8.4349   8.9340     9.4247
#
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# 打印参数
# encoder.weight_ih_l0    True
# encoder.weight_hh_l0    True
# encoder.bias_ih_l0    True
# encoder.bias_hh_l0    True
# decoder.weight_ih_l0    True
# decoder.weight_hh_l0    True
# decoder.bias_ih_l0    True
# decoder.bias_hh_l0    True
# decoder_output.weight    True
# decoder_output.bias    True
# alpha_hidden_1.weight    True
# alpha_hidden_1.bias    True
# alpha_hidden_2.weight    True
# alpha_hidden_2.bias    True
# alpha_out_1.weight    True
# alpha_out_1.bias    True
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:22<00:00,  4.44it/s]
# Best epoch: 49 | loss 1.3803016543388367
# ###  Train  Error/Accuracy Metrics ###
# [[  0 686]
#  [  0 770]]
# train score
# 1.0
# 0.0
# 0.5288461538461539
# [[  0 183]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# 打印参数
# encoder.weight_ih_l0    True
# encoder.weight_hh_l0    True
# encoder.bias_ih_l0    True
# encoder.bias_hh_l0    True
# decoder.weight_ih_l0    True
# decoder.weight_hh_l0    True
# decoder.bias_ih_l0    True
# decoder.bias_hh_l0    True
# decoder_output.weight    True
# decoder_output.bias    True
# alpha_hidden_1.weight    True
# alpha_hidden_1.bias    True
# alpha_hidden_2.weight    True
# alpha_hidden_2.bias    True
# alpha_out_1.weight    True
# alpha_out_1.bias    True
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:22<00:00,  4.45it/s]
# Best epoch: 5 | loss 1.3792340755462646
# ###  Train  Error/Accuracy Metrics ###
# [[  0 686]
#  [  0 770]]
# train score
# 1.0
# 0.0
# 0.5288461538461539
# [[  0 183]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# 打印参数
# encoder.weight_ih_l0    True
# encoder.weight_hh_l0    True
# encoder.bias_ih_l0    True
# encoder.bias_hh_l0    True
# decoder.weight_ih_l0    True
# decoder.weight_hh_l0    True
# decoder.bias_ih_l0    True
# decoder.bias_hh_l0    True
# decoder_output.weight    True
# decoder_output.bias    True
# alpha_hidden_1.weight    True
# alpha_hidden_1.bias    True
# alpha_hidden_2.weight    True
# alpha_hidden_2.bias    True
# alpha_out_1.weight    True
# alpha_out_1.bias    True
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:22<00:00,  4.42it/s]
# Best epoch: 37 | loss 1.3793496489524841
# ###  Train  Error/Accuracy Metrics ###
# [[  0 686]
#  [  0 770]]
# train score
# 1.0
# 0.0
# 0.5288461538461539
# [[  0 183]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:22<00:00,  4.44it/s]
# Best epoch: 13 | loss 1.3789714574813843
# ###  Train  Error/Accuracy Metrics ###
# [[  0 686]
#  [  0 770]]
# train score
# 1.0
# 0.0
# 0.5288461538461539
# [[  0 183]
#  [  0 181]]
# test score
# 1.0
# 0.0
# 0.49725274725274726
# 0.0
# 100
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:22<00:00,  4.45it/s]
# Best epoch: 96 | loss 1.3796458840370178
# ###  Train  Error/Accuracy Metrics ###
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:22<00:00,  4.49it/s]
# Best epoch: 84 | loss 1.380263864994049
# ###  Train  Error/Accuracy Metrics ###
# [[  0 686]
#  [  0 770]]
# train score
# 1.0
# 0.0
# 0.5288461538461539
# [[  0 183]
#  [  0 181]]
# test score
# 1.0
# 0.0
# 0.49725274725274726
# run over 4
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:22<00:00,  4.47it/s]
# Best epoch: 25 | loss 1.379898726940155
# ###  Train  Error/Accuracy Metrics ###
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# start run 4
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:22<00:00,  4.46it/s]
# Best epoch: 40 | loss 1.37967187166214
# ###  Train  Error/Accuracy Metrics ###
# [[  0 686]
#  [  0 770]]
# train score
# 1.0
# 0.0
# 0.5288461538461539
# [[  0 183]
#  [  0 181]]
# test score
# 1.0
# 0.0
# 0.49725274725274726
# end run 4
# start run 3
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
# 100%|██████████| 100/100 [00:23<00:00,  4.34it/s]
# Best epoch: 49 | loss 1.3808752298355103
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# start run 4

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# start run 2
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   5%|▍         | 4559/100000 [18:41<6:31:13,  4.07it/s]
# Best epoch: 4058 | loss 0.003358249901793897
# ###  Train  Error/Accuracy Metrics ###
# [[686   0]
#  [  4 766]]
# train score
# 0.9948051948051948
# 1.0
# 0.9972527472527473
# [[90 93]
#  [95 86]]
# test score
# 0.47513812154696133
# 0.4918032786885246
# 0.4835164835164835
# end run 2
# start run 3
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   1%|          | 701/100000 [02:47<6:36:05,  4.18it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# start run 3
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   5%|▍         | 4721/100000 [19:05<6:25:24,  4.12it/s]
# pass 500
# Best epoch: 4220 | loss 0.0017568815383128822
# ###  Train  Error/Accuracy Metrics ###
# [[686   0]
#  [  0 770]]
# train score
# 1.0
# 1.0
# 1.0
# [[107  76]
#  [ 76 105]]
# test score
# 0.580110497237569
# 0.5846994535519126
# 0.5824175824175825
# end run 3
# start run 4
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   6%|▌         | 5624/100000 [22:54<6:24:18,  4.09it/s]
# pass 500
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000001.sz
# start run 3
# train count
# 5728
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 5728
# Batches per Epoch:	 1
#   2%|▏         | 2147/100000 [31:00<23:32:53,  1.15it/s]
# pass 500
# Best epoch: 1646 | loss 0.003293080284493044
# ###  Train  Error/Accuracy Metrics ###
# [[3034    0]
#  [   0 2694]]
# train score
# 1.0
# 1.0
# 1.0
# [[415 329]
#  [343 345]]
# test score
# 0.501453488372093
# 0.5577956989247311
# 0.5307262569832403
# end run 3
# start run 4
# train count
# 5728
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 5728
# Batches per Epoch:	 1
#   4%|▍         | 4380/100000 [1:05:56<23:59:26,  1.11it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 3
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   0%|          | 131/100000 [00:29<6:15:32,  4.43it/s]

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 3
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   0%|          | 263/100000 [01:04<6:48:49,  4.07it/s]

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 3
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   7%|▋         | 6676/100000 [27:35<6:25:44,  4.03it/s]
# pass 1000
# Best epoch: 5675 | loss 0.0012781135155819356
# ###  Train  Error/Accuracy Metrics ###
# [[686   0]
#  [  0 770]]
# train score
# 1.0
# 1.0
# 1.0
# [[110  73]
#  [ 78 103]]
# test score
# 0.569060773480663
# 0.6010928961748634
# 0.5851648351648352
# end run 3
# start run 4
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   8%|▊         | 7931/100000 [32:47<6:20:34,  4.03it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 6
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#  33%|███▎      | 33444/100000 [2:32:10<5:02:50,  3.66it/s]
# pass 1000
# Best epoch: 32443 | loss 0.019093776121735573
# ###  Train  Error/Accuracy Metrics ###
# [[686   0]
#  [  0 770]]
# train score
# 1.0
# 1.0
# 1.0
# [[ 71 112]
#  [ 76 105]]
# test score
# 0.580110497237569
# 0.3879781420765027
# 0.4835164835164835
# end run 6

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 2
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   3%|▎         | 2813/100000 [11:33<6:39:07,  4.06it/s]
# loss is too small
# Best epoch: 2813 | loss 0.0002962941798614338
# ###  Train  Error/Accuracy Metrics ###
# [[686   0]
#  [  0 770]]
# train score
# 1.0
# 1.0
# 1.0
# [[ 98  85]
#  [101  80]]
# test score
# 0.4419889502762431
# 0.5355191256830601
# 0.489010989010989
# end run 2
# start run 1
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   3%|▎         | 2612/100000 [10:09<6:18:42,  4.29it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 1
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   3%|▎         | 2584/100000 [09:47<6:09:11,  4.40it/s]
# loss is too small
# Best epoch: 2584 | loss 0.0002890576215577312
# ###  Train  Error/Accuracy Metrics ###
# [[686   0]
#  [  0 770]]
# train score
# 1.0
# 1.0
# 1.0
# [[100  83]
#  [ 85  96]]
# test score
# 0.5303867403314917
# 0.546448087431694
# 0.5384615384615384
# end run 1
# start run 3
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   4%|▍         | 4348/100000 [16:17<5:58:23,  4.45it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 8
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   5%|▍         | 4940/100000 [18:55<6:04:00,  4.35it/s]
# pass 500
# Best epoch: 4439 | loss 0.004366619978100061
# ###  Train  Error/Accuracy Metrics ###
# [[686   0]
#  [  0 770]]
# train score
# 1.0
# 1.0
# 1.0
# [[101  82]
#  [ 75 106]]
# test score
# 0.585635359116022
# 0.5519125683060109
# 0.5686813186813187
# end run 8
# start run 9
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   5%|▍         | 4883/100000 [18:17<5:56:22,  4.45it/s]
# pass 500
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 10
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   6%|▌         | 5964/100000 [24:19<6:23:36,  4.09it/s]
# pass 500
# Best epoch: 5463 | loss 0.0030128699727356434
# ###  Train  Error/Accuracy Metrics ###
# [[686   0]
#  [  0 770]]
# train score
# 1.0
# 1.0
# 1.0
# [[ 77 106]
#  [ 75 106]]
# test score
# 0.585635359116022
# 0.4207650273224044
# 0.5027472527472527
# end run 10
# start run 11
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   7%|▋         | 7191/100000 [29:04<6:15:09,  4.12it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# 0
# start run 3
# train count
# 5728
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 5728
# Batches per Epoch:	 1
#   2%|▏         | 2147/100000 [34:23<26:07:09,  1.04it/s]
# pass 500
# Best epoch: 1646 | loss 0.003293080284493044
# ###  Train  Error/Accuracy Metrics ###
# [[3034    0]
#  [   0 2694]]
# train score
# 1.0
# 1.0
# 1.0
# [[415 329]
#  [343 345]]
# test score
# 0.501453488372093
# 0.5577956989247311
# 0.5307262569832403
# end run 3
# 1
# start run 3
# train count
# 5726
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	3.69MB
# Model Size:		3.29MB
# Model Parameters:	822730
# ------------------------------
# Data Size:		 5726
# Batches per Epoch:	 1
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000001.sz
# start run 3
# train count
# 5728
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	2.46MB
# Model Size:		3.28MB
# Model Parameters:	818887
# ------------------------------
# Data Size:		 5728
# Batches per Epoch:	 1
#   3%|▎         | 3078/100000 [47:12<24:46:19,  1.09it/s]
# pass 500
# Best epoch: 2577 | loss 0.0024146147770807147
# ###  Train  Error/Accuracy Metrics ###
# [[3034    0]
#  [   0 2694]]
# train score
# 1.0
# 1.0
# 1.0
# [[406 338]
#  [358 330]]
# test score
# 0.4796511627906977
# 0.5456989247311828
# 0.5139664804469274
# end run 3

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000002.sz
# start run 3
# train count
# 5726
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	2.46MB
# Model Size:		3.28MB
# Model Parameters:	818887
# ------------------------------
# Data Size:		 5726
# Batches per Epoch:	 1
#   5%|▍         | 4895/100000 [1:15:42<24:31:00,  1.08it/s]
# pass 500
# Best epoch: 4394 | loss 0.0018337232759222388
# ###  Train  Error/Accuracy Metrics ###
# [[2980    0]
#  [   0 2746]]
# train score
# 1.0
# 1.0
# 1.0
# [[434 319]
#  [358 320]]
# test score
# 0.471976401179941
# 0.5763612217795485
# 0.5269042627533194
# end run 3
# start run 3
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	2.46MB
# Model Size:		3.28MB
# Model Parameters:	818887
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   3%|▎         | 2892/100000 [11:45<6:30:23,  4.15it/s]

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 1
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	2.46MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#   5%|▍         | 4581/100000 [03:04<1:04:06, 24.81it/s]
# pass 500
# Best epoch: 4080 | loss 0.5766478776931763
# ###  Train  Error/Accuracy Metrics ###
# [[570 116]
#  [108 662]]
# train score
# 0.8597402597402597
# 0.8309037900874635
# 0.8461538461538461
# [[ 89  94]
#  [ 78 103]]
# test score
# 0.569060773480663
# 0.48633879781420764
# 0.5274725274725275
# end run 1

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 1
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 1456
# Batches per Epoch:	 1
#  12%|█▏        | 12266/100000 [08:43<1:02:21, 23.45it/s]
# pass 500
# Best epoch: 11765 | loss 0.043160224333405495
# ###  Train  Error/Accuracy Metrics ###
# [[683   3]
#  [  2 768]]
# train score
# 0.9974025974025974
# 0.9956268221574344
# 0.9965659340659341
# [[87 96]
#  [83 98]]
# test score
# 0.5414364640883977
# 0.47540983606557374
# 0.5082417582417582
# end run 1

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 1
# hidden_vector_size 64
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 1456
#   7%|▋         | 7168/100000 [05:05<1:05:57, 23.46it/s]
# pass 500
# Best epoch: 6667 | loss 0.38551148772239685
# ###  Train  Error/Accuracy Metrics ###
# [[631  55]
#  [ 58 712]]
# train score
# 0.9246753246753247
# 0.9198250728862973
# 0.9223901098901099
# [[ 74 109]
#  [ 82  99]]
# test score
# 0.5469613259668509
# 0.40437158469945356
# 0.47527472527472525
# end run 1

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 1
# hidden_vector_size 64
# train count
# 1456
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 1456
#  11%|█         | 11020/100000 [07:50<1:02:53, 23.58it/s]

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 0
# start run 1
# hidden_vector_size 64
# train count
# 6802
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6802
#  28%|██▊       | 277/1000 [00:54<02:18,  5.20it/s]

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000333.sz
# start run 1
# hidden_vector_size 64
# train count
# 1729
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 1729
# 100%|██████████| 500/500 [00:27<00:00, 18.16it/s]
# Best epoch: 498 | loss 0.09082290157675743
# ###  Train  Error/Accuracy Metrics ###
# [[  0 822]
#  [  0 907]]
# train score
# 1.0
# 0.0
# 0.5245806824754193
# [[ 0 47]
#  [ 0 44]]
# test score
# 1.0
# 0.0
# 0.4835164835164835
# end run 1

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000001.sz
# 0
# start run 1
# hidden_vector_size 64
# train count
# 6802
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6802
# 100%|██████████| 2000/2000 [06:39<00:00,  5.00it/s]
# Best epoch: 1995 | loss 0.11853268183767796
# ###  Train  Error/Accuracy Metrics ###
# [[  17 3571]
#  [  11 3203]]
# train score
# 0.9965774735532047
# 0.004738015607580825
# 0.47339017935901206
# [[  0 190]
#  [  0 168]]
# test score
# 1.0
# 0.0
# 0.4692737430167598
# end run 1
# 1
# start run 1
# hidden_vector_size 64
# train count
# 6800
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6800
# 100%|██████████| 2000/2000 [06:34<00:00,  5.07it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000001.sz
# 0
# start run 1
# hidden_vector_size 64
# train count
# 6802
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6802
# 100%|██████████| 2000/2000 [06:30<00:00,  5.12it/s]
# Best epoch: 1993 | loss 0.11287497077137232
# ###  Train  Error/Accuracy Metrics ###
# [[3588    0]
#  [3214    0]]
# train score
# 0.0
# 1.0
# 0.5274919141428992
# [[190   0]
#  [168   0]]
# test score
# 0.0
# 1.0
# 0.5307262569832403
# end run 1
# 1
# start run 1
# hidden_vector_size 64
# train count
# 6800
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6800
# 100%|██████████| 2000/2000 [06:42<00:00,  4.97it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000001.sz
# run 10
# start run 1
# hidden_vector_size 64
# train count
# 6656
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6656
# 100%|██████████| 2000/2000 [06:03<00:00,  5.50it/s]
# Best epoch: 1993 | loss 0.10858404915779829
# ###  Train  Error/Accuracy Metrics ###
# [[   0 3458]
#  [   0 3198]]
# train score
# 1.0
# 0.0
# 0.48046875
# [[  0 178]
#  [  0 172]]
# test score
# 1.0
# 0.0
# 0.49142857142857144
# end run 1
# run 11
# start run 1
# hidden_vector_size 64
# train count
# 6557
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6557
# 100%|██████████| 2000/2000 [06:16<00:00,  5.31it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000001.sz
# run 0
# start run 2
# hidden_vector_size 128
# train count
# 6802
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.83MB
# Model Parameters:	207719
# ------------------------------
# Data Size:		 6802
# 100%|██████████| 2000/2000 [14:49<00:00,  2.25it/s]
# Best epoch: 1992 | loss 0.07016490120440722
# ###  Train  Error/Accuracy Metrics ###
# [[ 143 3445]
#  [ 146 3068]]
# train score
# 0.95457373988799
# 0.03985507246376811
# 0.4720670391061452
# [[  1 189]
#  [  3 165]]
# test score
# 0.9821428571428571
# 0.005263157894736842
# 0.46368715083798884
# end run 2
# run 1
# start run 2
# hidden_vector_size 128
# train count
# 6800
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.83MB
# Model Parameters:	207719
# ------------------------------
# Data Size:		 6800
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 000006.sz
# start run 2
# hidden_vector_size 128
# train count
# 6540
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.83MB
# Model Parameters:	207719
# ------------------------------
# Data Size:		 6540
# 100%|██████████| 2000/2000 [14:12<00:00,  2.35it/s]
# Best epoch: 1984 | loss 0.06369276391342282
# ###  Train  Error/Accuracy Metrics ###
# [[   8 3359]
#  [  11 3162]]
# train score
# 0.9965332492908919
# 0.002376002376002376
# 0.4847094801223242
# [[  0 193]
#  [  0 151]]
# test score
# 1.0
# 0.0
# 0.438953488372093
# end run 2

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# run 000027.sz
# start run 1
# hidden_vector_size 64
# train count
# 6279
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6279
# 100%|██████████| 2000/2000 [06:46<00:00,  4.92it/s]
# Best epoch: 1991 | loss 0.11210605502128601
# ###  Train  Error/Accuracy Metrics ###
# [[   0 3229]
#  [   0 3050]]
# train score
# 1.0
# 0.0
# 0.48574613792005095
# [[  0 169]
#  [  0 161]]
# test score
# 1.0
# 0.0
# 0.48787878787878786
# end run 1
# run 000028.sz
# start run 1
# hidden_vector_size 64
# train count
# 6249
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6249
# 100%|██████████| 2000/2000 [06:49<00:00,  4.88it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# fuck
# run 000038.sz
# start run 1
# hidden_vector_size 64
# train count
# 4377
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 4377
# 100%|██████████| 2000/2000 [04:38<00:00,  7.18it/s]
# Best epoch: 1996 | loss 0.08323203027248383
# ###  Train  Error/Accuracy Metrics ###
# [[   0 2189]
#  [   0 2188]]
# train score
# 1.0
# 0.0
# 0.49988576650673977
# [[  0 137]
#  [  0  93]]
# test score
# 1.0
# 0.0
# 0.4043478260869565
# end run 1
# run 000039.sz
# start run 1
# hidden_vector_size 64
# train count
# 6163
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6163
# 100%|██████████| 2000/2000 [06:44<00:00,  4.94it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# fuck1
# run 000056.sz
# start run 1
# hidden_vector_size 64
# train count
# 5459
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5459
# 100%|██████████| 2000/2000 [05:30<00:00,  6.05it/s]
# Best epoch: 1992 | loss 0.10129186604171991
# ###  Train  Error/Accuracy Metrics ###
# [[   7 2757]
#  [   6 2689]]
# train score
# 0.997773654916512
# 0.002532561505065123
# 0.49386334493496975
# [[  1 158]
#  [  0 128]]
# test score
# 1.0
# 0.006289308176100629
# 0.44947735191637633
# end run 1
# run 000058.sz
# start run 1
# hidden_vector_size 64
# train count
# 5132
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5132
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# fuck2
# run 000153.sz
# start run 1
# hidden_vector_size 64
# train count
# 4399
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 4399
# 100%|██████████| 2000/2000 [04:14<00:00,  7.86it/s]
# Best epoch: 1987 | loss 0.08295734319835901
# ###  Train  Error/Accuracy Metrics ###
# [[   0 2151]
#  [   0 2248]]
# train score
# 1.0
# 0.0
# 0.5110252330075017
# [[  0 124]
#  [  0 107]]
# test score
# 1.0
# 0.0
# 0.46320346320346323
# end run 1
# run 000155.sz
# start run 1
# hidden_vector_size 64
# train count
# 4148
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 4148
# 100%|██████████| 2000/2000 [04:04<00:00,  8.17it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# fuck3
# run 000413.sz
# start run 1
# hidden_vector_size 64
# train count
# 5432
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5432
# 100%|██████████| 2000/2000 [05:24<00:00,  6.17it/s]
# Best epoch: 1976 | loss 0.0985026890411973
# ###  Train  Error/Accuracy Metrics ###
# [[   0 2764]
#  [   0 2668]]
# train score
# 1.0
# 0.0
# 0.49116347569955815
# [[  0 165]
#  [  0 120]]
# test score
# 1.0
# 0.0
# 0.42105263157894735
# end run 1
# run 000415.sz
# start run 1
# hidden_vector_size 64
# train count
# 5037
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5037
# 100%|██████████| 2000/2000 [04:57<00:00,  6.73it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# fuck4
# run 000504.sz
# start run 1
# hidden_vector_size 64
# train count
# 6006
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6006
# 100%|██████████| 2000/2000 [05:40<00:00,  5.87it/s]
# Best epoch: 1984 | loss 0.10836239997297525
# ###  Train  Error/Accuracy Metrics ###
# [[   0 3096]
#  [   0 2910]]
# train score
# 1.0
# 0.0
# 0.48451548451548454
# [[  0 169]
#  [  0 147]]
# test score
# 1.0
# 0.0
# 0.4651898734177215
# end run 1
# run 000505.sz
# start run 1
# hidden_vector_size 64
# train count
# 6164
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6164
# 100%|██████████| 2000/2000 [06:12<00:00,  5.37it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# fuck5
# run 000530.sz
# start run 1
# hidden_vector_size 64
# train count
# 6232
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6232
# 100%|██████████| 2000/2000 [06:28<00:00,  5.14it/s]
# Best epoch: 1986 | loss 0.10497744008898735
# ###  Train  Error/Accuracy Metrics ###
# [[   0 3122]
#  [   0 3110]]
# train score
# 1.0
# 0.0
# 0.49903722721437743
# [[  0 175]
#  [  0 152]]
# test score
# 1.0
# 0.0
# 0.4648318042813456
# end run 1
# run 000531.sz
# start run 1
# hidden_vector_size 64
# train count
# 6139
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6139
# 100%|██████████| 2000/2000 [06:08<00:00,  5.42it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# fuck6
# run 000538.sz
# start run 1
# hidden_vector_size 64
# train count
# 6115
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6115
# 100%|██████████| 2000/2000 [05:46<00:00,  5.77it/s]
# Best epoch: 1996 | loss 0.12374513689428568
# ###  Train  Error/Accuracy Metrics ###
# [[   0 3126]
#  [   0 2989]]
# train score
# 1.0
# 0.0
# 0.48879803761242846
# [[  0 166]
#  [  0 155]]
# test score
# 1.0
# 0.0
# 0.48286604361370716
# end run 1
# run 000539.sz
# start run 1
# hidden_vector_size 64
# train count
# 6151
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6151
# 100%|██████████| 2000/2000 [06:07<00:00,  5.44it/s]
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# fuck7
# index 132
# run 000544.sz
# start run 1
# hidden_vector_size 64
# train count
# 6150
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6150
# 100%|██████████| 2000/2000 [06:34<00:00,  5.07it/s]
# Best epoch: 1979 | loss 0.1131474026478827
# ###  Train  Error/Accuracy Metrics ###
# [[   0 3086]
#  [   0 3064]]
# train score
# 1.0
# 0.0
# 0.49821138211382116
# [[  0 178]
#  [  0 145]]
# test score
# 1.0
# 0.0
# 0.44891640866873067
# end run 1
# index 133
# run 000545.sz
# start run 1
# hidden_vector_size 64
# train count
# 5579
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5579
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 11111111111
# index 151
# run 000566.sz
# start run 1
# hidden_vector_size 64
# train count
# 5896
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5896
# 100%|██████████| 2000/2000 [05:59<00:00,  5.56it/s]
# Best epoch: 1981 | loss 0.10635683219879866
# ###  Train  Error/Accuracy Metrics ###
# [[   0 2979]
#  [   0 2917]]
# train score
# 1.0
# 0.0
# 0.49474219810040704
# [[  0 199]
#  [  0 111]]
# test score
# 1.0
# 0.0
# 0.3580645161290323
# end run 1
# index 152
# run 000567.sz
# start run 1
# hidden_vector_size 64
# train count
# 6127
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6127
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 22222
# index 181
# run 000608.sz
# start run 1
# hidden_vector_size 64
# train count
# 5394
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5394
# 100%|██████████| 2000/2000 [05:11<00:00,  6.41it/s]
# Best epoch: 1981 | loss 0.10984939616173506
# ###  Train  Error/Accuracy Metrics ###
# [[   1 2782]
#  [   1 2610]]
# train score
# 0.9996170049789352
# 0.00035932446999640676
# 0.4840563589173155
# [[  0 160]
#  [  0 123]]
# test score
# 1.0
# 0.0
# 0.43462897526501765
# end run 1
# index 182
# run 000609.sz
# start run 1
# hidden_vector_size 64
# train count
# 5510
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5510
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 33333333
# index 200
# run 000631.sz
# start run 1
# hidden_vector_size 64
# train count
# 4908
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 4908
# 100%|██████████| 2000/2000 [04:51<00:00,  6.85it/s]
# Best epoch: 1972 | loss 0.08703341241925955
# ###  Train  Error/Accuracy Metrics ###
# [[   0 2621]
#  [   0 2287]]
# train score
# 1.0
# 0.0
# 0.46597392013039934
# [[  0 142]
#  [  0 116]]
# test score
# 1.0
# 0.0
# 0.4496124031007752
# end run 1
# index 201
# run 000632.sz
# start run 1
# hidden_vector_size 64
# train count
# 5585
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5585
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 4444444
# index 230
# run 000681.sz
# start run 1
# hidden_vector_size 64
# train count
# 4357
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 4357
# 100%|██████████| 2000/2000 [04:27<00:00,  7.46it/s]
# Best epoch: 1990 | loss 0.0871624955907464
# ###  Train  Error/Accuracy Metrics ###
# [[  14 2270]
#  [   2 2071]]
# train score
# 0.9990352146647371
# 0.006129597197898424
# 0.47854028000918064
# [[  0 127]
#  [  0 102]]
# test score
# 1.0
# 0.0
# 0.44541484716157204
# end run 1
# index 231
# run 000682.sz
# start run 1
# hidden_vector_size 64
# train count
# 5303
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 5303
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 55555
# index 600
# run 002127.sz
# start run 1
# hidden_vector_size 64
# train count
# 2941
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 2941
# 100%|██████████| 2000/2000 [02:46<00:00, 11.99it/s]
# Best epoch: 1980 | loss 0.06490048114210367
# ###  Train  Error/Accuracy Metrics ###
# [[   0 1489]
#  [   0 1452]]
# train score
# 1.0
# 0.0
# 0.4937096225773546
# [[ 0 92]
#  [ 0 62]]
# test score
# 1.0
# 0.0
# 0.4025974025974026
# end run 1
# index 601
# run 002128.sz
# start run 1
# hidden_vector_size 64
# train count
# 3101
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 3101
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 6666
# index 620
# run 002148.sz
# start run 1
# hidden_vector_size 64
# train count
# 3116
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 3116
# 100%|██████████| 2000/2000 [03:10<00:00, 10.49it/s]
# Best epoch: 1997 | loss 0.07277114689350128
# ###  Train  Error/Accuracy Metrics ###
# [[   0 1524]
#  [   0 1592]]
# train score
# 1.0
# 0.0
# 0.5109114249037228
# [[ 0 75]
#  [ 0 89]]
# test score
# 1.0
# 0.0
# 0.5426829268292683
# end run 1
# index 621
# run 002149.sz
# start run 1
# hidden_vector_size 64
# train count
# 3018
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 3018
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 77777
# index 0
# run 000001.sz
# start run 1
# hidden_vector_size 64
# train count
# 6802
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6802
# 100%|██████████| 2000/2000 [06:37<00:00,  5.03it/s]
# Best epoch: 1992 | loss 0.11268736235797405
# ###  Train  Error/Accuracy Metrics ###
# [[   0 3588]
#  [   0 3214]]
# train score
# 1.0
# 0.0
# 0.47250808585710086
# [[  0 190]
#  [  0 168]]
# test score
# 1.0
# 0.0
# 0.4692737430167598
# end run 1
# index 1
# run 000002.sz
# start run 1
# hidden_vector_size 64
# train count
# 6800
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 6800
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 88888
# index 640
# run 002168.sz
# start run 1
# hidden_vector_size 64
# train count
# 2763
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 2763
# 100%|██████████| 2000/2000 [02:46<00:00, 12.03it/s]
# Best epoch: 1979 | loss 0.05881769675761461
# ###  Train  Error/Accuracy Metrics ###
# [[  17 1354]
#  [  15 1377]]
# train score
# 0.9892241379310345
# 0.012399708242159009
# 0.5045240680419834
# [[ 0 76]
#  [ 0 69]]
# test score
# 1.0
# 0.0
# 0.47586206896551725
# end run 1
# index 641
# run 002169.sz
# start run 1
# hidden_vector_size 64
# train count
# 3091
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.22MB
# Model Parameters:	55271
# ------------------------------
# Data Size:		 3091
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 33333
# here
# start run 3
# hidden_vector_size 128
# train count
# 6413
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6413
#   9%|▊         | 8666/100000 [54:07<9:09:57,  2.77it/s]

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 33333
# here1
# start run 3
# hidden_vector_size 128
# train count
# 6540
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6540
#   5%|▍         | 4845/100000 [32:02<10:29:16,  2.52it/s]
# pass 1000
# Best epoch: 3844 | loss 0.003375162836164236
# ###  Train  Error/Accuracy Metrics ###
# [[3367    0]
#  [   0 3173]]
# train score
# 1.0
# 1.0
# 1.0
# [[ 90 103]
#  [ 80  71]]
# test score
# 0.47019867549668876
# 0.46632124352331605
# 0.4680232558139535
# end run 3
# here1
# start run 3
# hidden_vector_size 128
# train count
# 6183
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6183
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 444444
# here2
# start run 3
# hidden_vector_size 128
# train count
# 6413
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6413
#   2%|▏         | 2377/100000 [15:19<10:29:06,  2.59it/s]
# pass 100
# Best epoch: 2276 | loss 2.4787880182266235
# ###  Train  Error/Accuracy Metrics ###
# [[3145  157]
#  [ 236 2875]]
# train score
# 0.9241401478624237
# 0.9524530587522714
# 0.93871822859816
# [[96 83]
#  [83 75]]
# test score
# 0.47468354430379744
# 0.5363128491620112
# 0.5074183976261127
# end run 3
# here2
# start run 3
# hidden_vector_size 128
# train count
# 6540
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6540
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 444444
# here2
# start run 4
# hidden_vector_size 128
# train count
# 6413
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6413
#   2%|▏         | 2002/100000 [12:14<9:59:31,  2.72it/s]
# pass 100
# Best epoch: 1901 | loss 8.721384644508362
# ###  Train  Error/Accuracy Metrics ###
# [[2479  823]
#  [1898 1213]]
# train score
# 0.3899067823850852
# 0.7507571168988492
# 0.5757055980040543
# [[130  49]
#  [109  49]]
# test score
# 0.310126582278481
# 0.7262569832402235
# 0.5311572700296736
# end run 4
# here2
# start run 4
# hidden_vector_size 128
# train count
# 6540
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6540
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 5555555
# here3
# start run 5
# hidden_vector_size 128
# train count
# 6413
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6413
#   1%|          | 1162/100000 [07:09<10:09:30,  2.70it/s]
# pass 100
# Best epoch: 1061 | loss 0.005346424266463146
# ###  Train  Error/Accuracy Metrics ###
# [[3302    0]
#  [   0 3111]]
# train score
# 1.0
# 1.0
# 1.0
# [[96 83]
#  [86 72]]
# test score
# 0.45569620253164556
# 0.5363128491620112
# 0.49851632047477745
# end run 5
# here3
# start run 5
# hidden_vector_size 128
# train count
# 6540
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6540
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 66666666
# here4
# start run 6
# hidden_vector_size 128
# train count
# 6413
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6413
#   1%|          | 1011/100000 [06:37<10:48:14,  2.55it/s]
# pass 100
# Best epoch: 910 | loss 0.06199240335263312
# ###  Train  Error/Accuracy Metrics ###
# [[3300    2]
#  [   0 3111]]
# train score
# 1.0
# 0.9993943064809206
# 0.9996881334788711
# [[88 91]
#  [67 91]]
# test score
# 0.5759493670886076
# 0.49162011173184356
# 0.5311572700296736
# end run 6
# here4
# start run 6
# hidden_vector_size 128
# train count
# 6540
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	1.23MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6540
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 66666666
# here4
# start run 7
# hidden_vector_size 128
# train count
# 6318
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	2.46MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6318
#   2%|▏         | 1684/100000 [20:01<19:29:17,  1.40it/s]
# pass 100
# Best epoch: 1583 | loss 0.19605918508023024
# ###  Train  Error/Accuracy Metrics ###
# [[3232    9]
#  [   9 3068]]
# train score
# 0.9970750731231719
# 0.9972230792965134
# 0.9971509971509972
# [[90 86]
#  [72 84]]
# test score
# 0.5384615384615384
# 0.5113636363636364
# 0.5240963855421686
# end run 7
# here4
# start run 7
# hidden_vector_size 128
# train count
# 6445
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	2.46MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 6445
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 777777777
# start run 8
# hidden_vector_size 128
# train count
# 5519
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	2.46MB
# Model Size:		0.86MB
# Model Parameters:	214983
# ------------------------------
# Data Size:		 5519
#   1%|          | 1035/100000 [11:02<17:59:38,  1.53it/s]

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 0000000000000000000000000
# start run 16
# hidden_vector_size 40
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.13MB
# Model Size:		0.10MB
# Model Parameters:	25457
# ------------------------------
# Data Size:		 12477
#   0%|          | 437/100000 [01:06<4:14:23,  6.52it/s]
# pass 100
# Best epoch: 336 | loss 11.103383749723434
# train count 12477
# ###  Train  Error/Accuracy Metrics ###
# [[8494  434]
#  [2228 1321]]
# train score
# 0.3722175260636799
# 0.9513888888888888
# 0.7866474312735433
# test count 3119
# [[2042  245]
#  [ 649  183]]
# test score
# 0.21995192307692307
# 0.8928727590730214
# 0.7133696697659506
# end run 16

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 0000000000000000000000000
# here
# start run 18
# hidden_vector_size 64
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.13MB
# Model Size:		0.25MB
# Model Parameters:	63697
# ------------------------------
# Data Size:		 12477
#   1%|          | 577/100000 [01:29<4:17:12,  6.44it/s]
# pass 100
# Best epoch: 476 | loss 11.562281042337418
# train count 12477
# ###  Train  Error/Accuracy Metrics ###
# [[7592  354]
#  [2701 1830]]
# train score
# 0.4038843522401236
# 0.9554492826579412
# 0.7551494750340627
# test count 3119
# [[1740  329]
#  [ 848  202]]
# test score
# 0.19238095238095237
# 0.8409859835669405
# 0.62263546008336
# end run 18
# here
# start run 18
# hidden_vector_size 64
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.13MB
# Model Size:		0.25MB
# Model Parameters:	63697
# ------------------------------
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 11111111
# here
# start run 18
# hidden_vector_size 64
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.05MB
# Model Size:		0.24MB
# Model Parameters:	60487
# ------------------------------
# Data Size:		 12477
#   1%|          | 1127/100000 [02:56<4:17:21,  6.40it/s]
# pass 100
# Best epoch: 1026 | loss 0.009141949805780314
# train count 12477
# ###  Train  Error/Accuracy Metrics ###
# [[7946    0]
#  [   1 4530]]
# train score
# 0.9997792981681748
# 1.0
# 0.9999198525286527
# test count 3119
# [[1365  704]
#  [ 687  363]]
# test score
# 0.3457142857142857
# 0.6597390043499275
# 0.5540237255530619
# end run 18
# here
# start run 18
# hidden_vector_size 64
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.05MB
# Model Size:		0.24MB
# Model Parameters:	60487
# ------------------------------
# Data Size:		 12477
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 1111111111
# start run 1
# hidden_vector_size 40
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'CUMLOGRET_1', 'CUMPCTRET_1', 'SMA_15', 'SMA_30', 'SMA_45', 'EMA_15', 'EMA_30', 'EMA_45', 'RSI_30', 'K_30_3', 'D_30_3', 'J_30_3', 'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.13MB
# Model Size:		0.11MB
# Model Parameters:	26462
# ------------------------------
# Data Size:		 798
#   2%|▏         | 1524/100000 [00:17<18:56, 86.62it/s]
# pass 100
# Best epoch: 1423 | loss 0.02126581035554409
# train count 798
# ###  Train  Error/Accuracy Metrics ###
# [[557   1]
#  [  2 238]]
# train score
# 0.9916666666666667
# 0.9982078853046595
# 0.9962406015037594
# test count 199
# [[83 45]
#  [41 30]]
# test score
# 0.4225352112676056
# 0.6484375
# 0.5678391959798995
# end run 1
# hidden_vector_size 40
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 333333
# start run 1
# hidden_vector_size 40
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'CUMLOGRET_1', 'CUMPCTRET_1']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.05MB
# Model Size:		0.10MB
# Model Parameters:	23849
# ------------------------------
# Data Size:		 12478
#   1%|▏         | 1472/100000 [03:43<4:09:15,  6.59it/s]
# pass 100
# Best epoch: 1371 | loss 1.135810162872076
# train count 12478
# ###  Train  Error/Accuracy Metrics ###
# [[8850   78]
#  [  87 3463]]
# train score
# 0.9754929577464789
# 0.991263440860215
# 0.9867767270395896
# test count 3119
# [[1693  594]
#  [ 529  303]]
# test score
# 0.3641826923076923
# 0.740271097507652
# 0.6399487015068932
# end run 1
# hidden_vector_size 40
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'CUMLOGRET_1', 'CUMPCTRET_1', 'SMA_15', 'SMA_30', 'SMA_60', 'SMA_120']
# Using cuda
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 333333
# start run sp 3
# start run sp_ta 17
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.06MB
# Model Size:		0.09MB
# Model Parameters:	23447
# ------------------------------
# Data Size:		 12476
#   1%|          | 855/100000 [02:13<4:18:28,  6.39it/s]
# pass 100
# Best epoch: 754 | loss 0.0029346634983085096
# train count 12476
# ###  Train  Error/Accuracy Metrics ###
# [[8927    0]
#  [   0 3549]]
# train score
# 1.0
# 1.0
# 1.0
# test count 3119
# [[1683  604]
#  [ 550  282]]
# test score
# 0.3389423076923077
# 0.7358985570616529
# 0.6300096184674575
# end run 3
# start run sp_ta 18
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'BIAS_SMA_5', 'BIAS_SMA_10', 'BIAS_SMA_15', 'BIAS_SMA_20']
# Using cuda
# Using GPU: Tesla T4
# binary
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 333333
# start run sp 3
# start run sp_ta 31
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.06MB
# Model Size:		0.09MB
# Model Parameters:	23447
# ------------------------------
# Data Size:		 12476
#   1%|          | 855/100000 [02:12<4:16:34,  6.44it/s]
# pass 100
# Best epoch: 754 | loss 0.0029346634983085096
# train count 12476
# ###  Train  Error/Accuracy Metrics ###
# [[8927    0]
#  [   0 3549]]
# train score
# 1.0
# 1.0
# 1.0
# test count 3119
# [[1683  604]
#  [ 550  282]]
# test score
# 0.3389423076923077
# 0.7358985570616529
# 0.6300096184674575
# end run 3
# start run sp_ta 32
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'amount_XA_None']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 333333
# start run sp 3
# start run sp_ta 39
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'DPO_5', 'DPO_10', 'DPO_15', 'DPO_20']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.10MB
# Model Size:		0.10MB
# Model Parameters:	24251
# ------------------------------
# Data Size:		 12476
#   1%|          | 683/100000 [01:43<4:11:25,  6.58it/s]
# loss is too small
# Best epoch: 683 | loss 9.81164198492479e-05
# train count 12476
# ###  Train  Error/Accuracy Metrics ###
# [[8927    0]
#  [   0 3549]]
# train score
# 1.0
# 1.0
# 1.0
# test count 3119
# [[2121  166]
#  [ 161  671]]
# test score
# 0.8064903846153846
# 0.9274158285964145
# 0.895158704713049
# end run 3

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 333333
# start run sp 3
# start run sp_ta 42
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'EMA_5', 'EMA_10', 'EMA_15', 'EMA_20']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.10MB
# Model Size:		0.10MB
# Model Parameters:	24251
# ------------------------------
# Data Size:		 12476
#   1%|          | 853/100000 [02:10<4:13:13,  6.53it/s]
# pass 100
# Best epoch: 752 | loss 0.004615812853444368
# train count 12476
# ###  Train  Error/Accuracy Metrics ###
# [[8927    0]
#  [   0 3549]]
# train score
# 1.0
# 1.0
# 1.0
# test count 3119
# [[1735  552]
#  [ 549  283]]
# test score
# 0.3401442307692308
# 0.7586357673808483
# 0.6470022443090734
# end run 3
# start run sp_ta 43
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'ENTP_5', 'ENTP_10', 'ENTP_15', 'ENTP_20']
# Using cuda
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 333333
# start run sp 3
# start run sp_ta 61
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'KCLe_5_2', 'KCBe_5_2', 'KCUe_5_2', 'KCLe_10_2', 'KCBe_10_2', 'KCUe_10_2', 'KCLe_15_2', 'KCBe_15_2', 'KCUe_15_2', 'KCLe_20_2', 'KCBe_20_2', 'KCUe_20_2']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.18MB
# Model Size:		0.10MB
# Model Parameters:	25859
# ------------------------------
# Data Size:		 12476
#   1%|          | 746/100000 [02:10<4:48:51,  5.73it/s]
# pass 100
# Best epoch: 645 | loss 0.021822592258104123
# train count 12476
# ###  Train  Error/Accuracy Metrics ###
# [[8925    2]
#  [   0 3549]]
# train score
# 1.0
# 0.9997759605690602
# 0.9998396922090413
# test count 3119
# [[1678  609]
#  [ 517  315]]
# test score
# 0.3786057692307692
# 0.7337122868386533
# 0.6389868547611414
# end run 3
# start run sp_ta 62
# hidden_vector_size 40
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 333333
# start run sp 3
# start run sp_ta 91
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'PVR']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.07MB
# Model Size:		0.09MB
# Model Parameters:	23648
# ------------------------------
# Data Size:		 12476
#   1%|          | 621/100000 [01:37<4:19:54,  6.37it/s]
# pass 100
# Best epoch: 520 | loss 0.004590208387526218
# train count 12476
# ###  Train  Error/Accuracy Metrics ###
# [[8927    0]
#  [   0 3549]]
# train score
# 1.0
# 1.0
# 1.0
# test count 3119
# [[1709  578]
#  [ 542  290]]
# test score
# 0.3485576923076923
# 0.7472671622212506
# 0.640910548252645
# end run 3
# start run sp_ta 92
# hidden_vector_size 40
# xxxxx
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'PVT']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# ...

# %%
# %run main.py
# Out:
# 1.10.1+cu102
# True
# main
# 444444
# start run sp 3
# start run sp_ta 62
# hidden_vector_size 40
# 1111111
# features_x  ['open', 'high', 'low', 'close', 'amount', 'volume', 'K_5_3', 'D_5_3', 'J_5_3', 'K_10_3', 'D_10_3', 'J_10_3', 'K_15_3', 'D_15_3', 'J_15_3', 'K_30_3', 'D_30_3', 'J_30_3', 'K_60_3', 'D_60_3', 'J_60_3', 'K_120_3', 'D_120_3', 'J_120_3', 'K_180_3', 'D_180_3', 'J_180_3']
# Using cuda
# Using GPU: Tesla T4
# binary
# 打印参数
# 打印参数结束
# ------------------------------
# Data Batch Size:	0.28MB
# Model Size:		0.11MB
# Model Parameters:	27668
# ------------------------------
# Data Size:		 12476
#   1%|▏         | 1305/100000 [03:27<4:21:59,  6.28it/s]
# pass 100
# Best epoch: 1204 | loss 10.63756412267685
# train count 12476
# ###  Train  Error/Accuracy Metrics ###
# [[8678  249]
#  [2317 1232]]
# train score
# 0.34714003944773175
# 0.9721070908479893
# 0.7943251042000641
# test count 3119
# [[2060  227]
#  [ 682  150]]
# test score
# 0.18028846153846154
# 0.9007433318758199
# ...
